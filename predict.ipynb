# %%
import joblib
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r"D:\summer 2_nd\Formula 1\binary_dataset.csv",index_col= 0)

# %%
pd.set_option("display.max_columns",0)
df.head()
# Out:
#             race_name   driverRef  driverst_points  ...  avg_windspeed  avg_precip  avg_humidity
# 0  Bahrain Grand Prix    hamilton             15.0  ...          25.55         0.0          20.5
# 1  Bahrain Grand Prix      alonso              2.0  ...          25.55         0.0          20.5
# 2  Bahrain Grand Prix  hulkenberg              0.0  ...          25.55         0.0          20.5
# 3  Bahrain Grand Prix       perez              0.0  ...          25.55         0.0          20.5
# 4  Bahrain Grand Prix   ricciardo              0.0  ...          25.55         0.0          20.5
#
# [5 rows x 27 columns]

# %%
last_race_per_driver_per_track = df.drop_duplicates(subset=['driverRef', 'race_name'], keep='last')

# %%
last_race_per_driver_per_track["driverRef"].unique()
# Out:
# array(['latifi', 'mick_schumacher', 'stroll', 'vettel', 'albon',
#        'hamilton', 'alonso', 'perez', 'ricciardo', 'bottas',
#        'max_verstappen', 'sainz', 'ocon', 'gasly', 'norris', 'russell',
#        'zhou', 'tsunoda', 'de_vries', 'sargeant', 'kevin_magnussen',
#        'hulkenberg', 'leclerc', 'lawson', 'piastri', 'bearman',
#        'colapinto', 'doohan'], dtype=object)

# %%
last_race_per_driver_per_track[""].unique()

# %%
driver_updates = {
    "piastri": {
        "driverst_points": 234,
        "driverst_position": 1,
        "driverst_wins": 7,
        "css_points": 460,         # McLaren's constructor points
        "css_position": 1,
        "css_wins": 5,
        "constructorRef": "mclaren"
    },
    "norris": {
        "driverst_points": 226,
        "driverst_position": 2,
        "driverst_wins": 4,
        "css_points": 460,
        "css_position": 1,
        "css_wins": 5,
        "constructorRef": "mclaren"
    },
    "verstappen": {
        "driverst_points": 165,
        "driverst_position": 3,
        "driverst_wins": 0,
        "css_points": 172,         # Red Bull's points
        "css_position": 4,
        "css_wins": 3,
        "constructorRef": "red_bull"
    },
    "russell": {
        "driverst_points": 147,
        "driverst_position": 4,
        "driverst_wins": 1,
        "css_points": 210,         # Mercedes' points
        "css_position": 3,
        "css_wins": 2,
        "constructorRef": "mercedes"
    },
    "leclerc": {
        "driverst_points": 119,
        "driverst_position": 5,
        "driverst_wins": 0,
        "css_points": 222,         # Ferrari's points
        "css_position": 2,
        "css_wins": 2,
        "constructorRef": "ferrari"
    },
    "hamilton": {
        "driverst_points": 103,
        "driverst_position": 6,
        "driverst_wins": 0,
        "css_points": 222,
        "css_position": 2,
        "css_wins": 2,
        "constructorRef": "ferrari"
    },
    "antonelli": {
        "driverst_points": 63,
        "driverst_position": 7,
        "driverst_wins": 0,
        "css_points": 210,
        "css_position": 3,
        "css_wins": 2,
        "constructorRef": "mercedes"
    },
    "albon": {
        "driverst_points": 46,
        "driverst_position": 8,
        "driverst_wins": 0,
        "css_points": 59,          # Williams
        "css_position": 5,
        "css_wins": 0,
        "constructorRef": "williams"
    },
    "hulkenberg": {
        "driverst_points": 37,
        "driverst_position": 9,
        "driverst_wins": 0,
        "css_points": 41,          # Sauber / Kick Sauber
        "css_position": 6,
        "css_wins": 0,
        "constructorRef": "sauber"
    },
    "ocon": {
        "driverst_points": 23,
        "driverst_position": 10,
        "driverst_wins": 0,
        "css_points": 29,          # Haas
        "css_position": 9,
        "css_wins": 0,
        "constructorRef": "haas"
    },
    "hadjar": {
        "driverst_points": 21,
        "driverst_position": 11,
        "driverst_wins": 0,
        "css_points": 36,          # Racing Bulls (Red Bull junior)
        "css_position": 7,
        "css_wins": 0,
        "constructorRef": "racing_bulls"
    },
    "stroll": {
        "driverst_points": 20,
        "driverst_position": 12,
        "driverst_wins": 0,
        "css_points": 36,          # Aston Martin
        "css_position": 8,
        "css_wins": 0,
        "constructorRef": "aston_martin"
    },
    "gasly": {
        "driverst_points": 19,
        "driverst_position": 13,
        "driverst_wins": 0,
        "css_points": 19,          # Alpine
        "css_position": 10,
        "css_wins": 0,
        "constructorRef": "alpine"
    },
    "alonso": {
        "driverst_points": 16,
        "driverst_position": 14,
        "driverst_wins": 0,
        "css_points": 36,          # Aston Martin
        "css_position": 8,
        "css_wins": 0,
        "constructorRef": "aston_martin"
    },
    "sainz": {
        "driverst_points": 13,
        "driverst_position": 15,
        "driverst_wins": 0,
        "css_points": 59,          # Williams
        "css_position": 5,
        "css_wins": 0,
        "constructorRef": "williams"
    },
    "lawson": {
        "driverst_points": 12,
        "driverst_position": 16,
        "driverst_wins": 0,
        "css_points": 36,          # Racing Bulls
        "css_position": 7,
        "css_wins": 0,
        "constructorRef": "racing_bulls"
    },
    "tsunoda": {
        "driverst_points": 10,
        "driverst_position": 17,
        "driverst_wins": 0,
        "css_points": 172,         # Red Bull Racing team includes Tsunoda
        "css_position": 4,
        "css_wins": 0,
        "constructorRef": "red_bull"
    },
    "bearman": {
        "driverst_points": 6,
        "driverst_position": 18,
        "driverst_wins": 0,
        "css_points": 29,          # Haas
        "css_position": 9,
        "css_wins": 0,
        "constructorRef": "haas"
    },
    "bortoleto": {
        "driverst_points": 4,
        "driverst_position": 19,
        "driverst_wins": 0,
        "css_points": 41,          # Sauber
        "css_position": 6,
        "css_wins": 0,
        "constructorRef": "sauber"
    },
    "colapinto": {
        "driverst_points": 0,
        "driverst_position": 20,
        "driverst_wins": 0,
        "css_points": 19,          # Alpine
        "css_position": 10,
        "css_wins": 0,
        "constructorRef": "alpine"
    },
    "doohan": {
        "driverst_points": 0,
        "driverst_position": 21,
        "driverst_wins":0,
        "css_points": 19,          # Alpine
        "css_position": 0,
        "css_wins": 0,
        "constructorRef": "alpine"
    }
}
for driver, updates in driver_updates.items():
    mask = last_race_per_driver_per_track["driverRef"] == driver
    for col, val in updates.items():
        last_race_per_driver_per_track.loc[mask, col] = val

# %%
last_race_per_driver_per_track
# Out:
#                      race_name        driverRef  driverst_points  ...  avg_windspeed  avg_precip  avg_humidity
# 15          Bahrain Grand Prix           latifi              0.0  ...          25.55         0.0          20.5
# 17          Bahrain Grand Prix  mick_schumacher              0.0  ...          25.55         0.0          20.5
# 26    Saudi Arabian Grand Prix           stroll             20.0  ...          23.70         0.0          39.0
# 46       Australian Grand Prix           latifi              0.0  ...          15.05         0.0          85.0
# 48       Australian Grand Prix  mick_schumacher              0.0  ...          15.05         0.0          85.0
# ...                        ...              ...              ...  ...            ...         ...           ...
# 1188      Abu Dhabi Grand Prix          tsunoda             10.0  ...          10.70         0.0          23.5
# ...

# %%
avg_positions = {
  "norris": 1.0,
  "piastri": 2.333,
  "leclerc": 2.5,
  "hamilton": 4.0,
  "russell": 7.5,
  "verstappen": 5.0,
  "hulkenberg": 6.0,
  "albon": 8.0,
  "ocon": 10.0,
  "hadjar": 13.0,
  "stroll": 11.5,
  "gasly": 6.0,
  "alonso": 10.0,
  "sainz": 12.0,
  "lawson": 6.0,
  "tsunoda": 16.0,
  "bearman": 7.0,
  "bortoleto": 8.0,
}

for driver, avg in avg_positions.items():
    mask = last_race_per_driver_per_track['driverRef'] == driver
    last_race_per_driver_per_track.loc[mask, 'driver_avg_finish_last_3'] = avg

# %%
last_race_per_driver_per_track.drop(columns=["is_podium"],inplace=True)

# %%
last_race_per_driver_per_track.to_csv(r"D:\summer 2_nd\Formula 1\database.csv")

# %%
pipeline_p = joblib.load(r"D:\summer 2_nd\Formula 1\f1_preprocessing_pipeline.pkl")
model = joblib.load(r"D:\summer 2_nd\Formula 1\model.pkl")

# %%
first_rwo = last_race_per_driver_per_track.iloc[[0]]
trans = pipeline_p.transform(first_rwo)
print(trans.shape)
hello = model.predict(trans)
print(hello)
hell = (model.predict_proba(trans)[0])
print(hell)
# Out:
# (1, 85)
# [0]
# [1. 0.]
